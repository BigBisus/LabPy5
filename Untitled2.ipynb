# %% [markdown]
# <a href="https://colab.research.google.com/github/BigBisus/LabPy5/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Сделанно и Работает в GoogleColab
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 100)
y= np.sin(x)
z= np.cos(x)
plt.plot(x,y,'r',label='График 1')
plt.plot(x,z,'b--',label='График 2')
plt.legend()
plt.xlabel("X")
plt.ylabel("Y or Z")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Сделанно и Работает в GoogleColab
import numpy as np
import matplotlib.pyplot as plt
from numpy import random
G = np.random.normal(500, 2, 1000)
plt.hist(G, bins=20, color='blue')
plt.show()

# %%
#Сделанно и Работает в GoogleColab
import numpy as np
import matplotlib.pyplot as plt
from numpy import random
M= np.random.randint(1, 11, (5, 5))
average = np.mean(M)
Max = np.max(M)
Min = np.min(M)
SumCol= np.sum(M,axis=0)
print(M)
print(average)
print(Max)
print(Min)
print(SumCol)
# Out:
# [[9 2 7 7 5]
#  [7 4 7 6 8]
#  [5 1 7 1 6]
#  [2 7 1 5 5]
#  [4 2 1 3 4]]
# 4.64
# 9
# 1
# [27 16 23 22 28]

# %%
#Сделанно и Работает в GoogleColab
import numpy as np
import matplotlib.pyplot as plt
from numpy import random
M= np.random.randint(1, 11, (5, 5))

plt.imshow(M, cmap='viridis')
for i in range(5):
  for g in range(5):
    plt.text(i, g, (i , g))
plt.colorbar()
plt.show()

# %%
#Сделанно и Работает в GoogleColab
import numpy as np
import matplotlib.pyplot as plt

# Создаём 3 области
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Три типа графиков')

# 1. Линейный график y = x^2
x = np.linspace(0, 100, 100)
y = x ** 2
ax1.plot(x, y, color='blue')
ax1.set_title('Линейный график y = x²')
ax1.set_xlabel('x')
ax1.set_ylabel('y')

# 2. Точечный график случайных точек
np.random.seed(42)  # Для воспроизводимости
x_rand = np.random.rand(50) * 10
y_rand = np.random.rand(50) * 100
ax2.scatter(x_rand, y_rand, color='green', alpha=0.6)
ax2.set_title('Случайные точки')
ax2.set_xlabel('x')
ax2.set_ylabel('y')

# 3. Столбчатая диаграмма для категориальных данных
categories = ['A', 'B', 'C']
values = [3, 7, 2]
ax3.bar(categories, values, color=['red', 'green', 'blue'])
ax3.set_title('Столбчатая диаграмма')
ax3.set_xlabel('Категории')
ax3.set_ylabel('Значения')


# Показываем график
plt.show()
'''from numpy import random
from random import randint
data = np.random.rand(10, 10)
def p_function(x: float) -> float:
    return x**2
x = [1, 2, 3, 4, 5]
y = [p_function(t) for t in x]
plt.subplot(1, 3, 1)
plt.title("1")
plt.plot(x, y)

M= randint(-4, 4) % 100
B= randint(-4, 4) % 100
x = np.arange(M, B, 0.5)
y = np.cos(x)
plt.subplot(1, 3, 2)
plt.title("2")
plt.scatter(x, y)

plt.show()
'''
# Out:
# 'from numpy import random\nfrom random import randint\ndata = np.random.rand(10, 10)\ndef p_function(x: float) -> float:\n    return x**2\nx = [1, 2, 3, 4, 5]\ny = [p_function(t) for t in x]\nplt.subplot(1, 3, 1)\nplt.title("1")\nplt.plot(x, y)\n\nM= randint(-4, 4) % 100\nB= randint(-4, 4) % 100\nx = np.arange(M, B, 0.5)\ny = np.cos(x)\nplt.subplot(1, 3, 2)\nplt.title("2")\nplt.scatter(x, y)\n\nplt.show()\n'
